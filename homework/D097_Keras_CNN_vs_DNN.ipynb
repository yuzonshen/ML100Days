# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D

#import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop, Adam
import os

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

from keras.utils import np_utils
# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
#把LABEL轉成NUMERICAL Categorical -oneHot encoding
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# <h3>由於 DNN 只能輸入"一維"的資料</h3>，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1573376
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 6ms/step - loss: 2.1196 - accuracy: 0.2536 - val_loss: 1.8726 - val_accuracy: 0.3126
# Epoch 2/10
# 391/391 [==============================] - 2s 6ms/step - loss: 1.8623 - accuracy: 0.3256 - val_loss: 1.7729 - val_accuracy: 0.3550
# Epoch 3/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.7826 - accuracy: 0.3614 - val_loss: 1.6893 - val_accuracy: 0.4016
# Epoch 4/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.7263 - accuracy: 0.3800 - val_loss: 1.6420 - val_accuracy: 0.4138
# Epoch 5/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.6952 - accuracy: 0.3920 - val_loss: 1.6330 - val_accuracy: 0.4231
# Epoch 6/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.6689 - accuracy: 0.4032 - val_loss: 1.6644 - val_accuracy: 0.4196
# Epoch 7/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.6446 - accuracy: 0.4112 - val_loss: 1.6115 - val_accuracy: 0.4317
# Epoch 8/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.6261 - accuracy: 0.4186 - val_loss: 1.6142 - val_accuracy: 0.4322
# Epoch 9/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.6118 - accuracy: 0.4253 - val_loss: 1.5761 - val_accuracy: 0.4533
# Epoch 10/10
# 391/391 [==============================] - 2s 5ms/step - loss: 1.5960 - accuracy: 0.4283 - val_loss: 1.5493 - val_accuracy: 0.4561
# Test loss: 1.5493274927139282
# Test accuracy: 0.4560999870300293

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

from keras.utils import np_utils
# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
#把LABEL轉成NUMERICAL Categorical -oneHot encoding
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  activation_1 (Activation)   (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout_2 (Dropout)         (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  activation_2 (Activation)   (None, 15, 15, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense_3 (Dense)             (None, 512)               1180160
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 10)                5130
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 15s 14ms/step - loss: 1.7898 - accuracy: 0.3552 - val_loss: 1.5252 - val_accuracy: 0.4590
# Epoch 2/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.3387 - accuracy: 0.5248 - val_loss: 1.1513 - val_accuracy: 0.5922
# Epoch 3/10
# 391/391 [==============================] - 5s 12ms/step - loss: 1.1339 - accuracy: 0.5994 - val_loss: 0.9839 - val_accuracy: 0.6567
# Epoch 4/10
# 391/391 [==============================] - 5s 12ms/step - loss: 1.0001 - accuracy: 0.6500 - val_loss: 0.9609 - val_accuracy: 0.6679
# Epoch 5/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.9016 - accuracy: 0.6858 - val_loss: 0.7954 - val_accuracy: 0.7270
# Epoch 6/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.8297 - accuracy: 0.7093 - val_loss: 0.7540 - val_accuracy: 0.7355
# Epoch 7/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.7798 - accuracy: 0.7297 - val_loss: 0.7798 - val_accuracy: 0.7328
# Epoch 8/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.7336 - accuracy: 0.7446 - val_loss: 0.8335 - val_accuracy: 0.7145
# Epoch 9/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.6921 - accuracy: 0.7610 - val_loss: 0.8317 - val_accuracy: 0.7298
# Epoch 10/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.6725 - accuracy: 0.7710 - val_loss: 0.8286 - val_accuracy: 0.7392
# Test loss: 0.828636109828949
# Test accuracy: 0.7391999959945679

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?

# %% [markdown]
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
# > 調整增加卷積層Conv2D的filter個數, 對正確率有明顯提升, 但參數量也跟著增加; 調整MaxPooling2D為AveragePooling2D, 差異不大.
#
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?
# > DNN模型的參數數量較多, 因為CNN卷積層及池化層可以將圖片像素降維, 參數量可減少.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 30, 30, 32)        896
#
#  activation_6 (Activation)   (None, 30, 30, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 32)        9248
#
#  activation_7 (Activation)   (None, 28, 28, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 64)        18496
#
#  activation_8 (Activation)   (None, 12, 12, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 64)        36928
#
#  activation_9 (Activation)   (None, 10, 10, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 5, 5, 64)          0
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_5 (Dense)             (None, 512)               819712
#
#  activation_10 (Activation)  (None, 512)               0
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 10)                5130
#
#  activation_11 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 890,410
# Trainable params: 890,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 13ms/step - loss: 1.7480 - accuracy: 0.3662 - val_loss: 1.4200 - val_accuracy: 0.4779
# Epoch 2/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.3427 - accuracy: 0.5235 - val_loss: 1.2634 - val_accuracy: 0.5499
# Epoch 3/10
# 391/391 [==============================] - 5s 12ms/step - loss: 1.1518 - accuracy: 0.5944 - val_loss: 1.0597 - val_accuracy: 0.6282
# Epoch 4/10
# 391/391 [==============================] - 5s 12ms/step - loss: 1.0255 - accuracy: 0.6398 - val_loss: 0.9674 - val_accuracy: 0.6666
# Epoch 5/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.9411 - accuracy: 0.6716 - val_loss: 0.8627 - val_accuracy: 0.7002
# Epoch 6/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.8752 - accuracy: 0.6955 - val_loss: 0.9220 - val_accuracy: 0.6802
# Epoch 7/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.8192 - accuracy: 0.7154 - val_loss: 0.8903 - val_accuracy: 0.6968
# Epoch 8/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.7803 - accuracy: 0.7296 - val_loss: 0.7721 - val_accuracy: 0.7395
# Epoch 9/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.7436 - accuracy: 0.7428 - val_loss: 0.7774 - val_accuracy: 0.7333
# Epoch 10/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.7093 - accuracy: 0.7537 - val_loss: 0.7663 - val_accuracy: 0.7380
# Test loss: 0.766295850276947
# Test accuracy: 0.7379999756813049

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 30, 30, 64)        1792
#
#  activation_12 (Activation)  (None, 30, 30, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 64)        36928
#
#  activation_13 (Activation)  (None, 28, 28, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 128)       73856
#
#  activation_14 (Activation)  (None, 12, 12, 128)       0
#
#  conv2d_11 (Conv2D)          (None, 10, 10, 128)       147584
#
#  activation_15 (Activation)  (None, 10, 10, 128)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 128)         0
#
#  flatten_2 (Flatten)         (None, 3200)              0
#
#  dense_7 (Dense)             (None, 512)               1638912
#
#  activation_16 (Activation)  (None, 512)               0
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_8 (Dense)             (None, 10)                5130
#
#  activation_17 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 9s 21ms/step - loss: 1.8368 - accuracy: 0.3329 - val_loss: 1.4518 - val_accuracy: 0.4736
# Epoch 2/10
# 391/391 [==============================] - 7s 19ms/step - loss: 1.3149 - accuracy: 0.5360 - val_loss: 1.0374 - val_accuracy: 0.6342
# Epoch 3/10
# 391/391 [==============================] - 8s 19ms/step - loss: 1.0714 - accuracy: 0.6242 - val_loss: 0.9784 - val_accuracy: 0.6519
# Epoch 4/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.9078 - accuracy: 0.6842 - val_loss: 0.8638 - val_accuracy: 0.7086
# Epoch 5/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.8154 - accuracy: 0.7198 - val_loss: 0.8292 - val_accuracy: 0.7238
# Epoch 6/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.7432 - accuracy: 0.7462 - val_loss: 0.9435 - val_accuracy: 0.6829
# Epoch 7/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.6873 - accuracy: 0.7639 - val_loss: 0.8708 - val_accuracy: 0.7201
# Epoch 8/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.6470 - accuracy: 0.7774 - val_loss: 0.7415 - val_accuracy: 0.7531
# Epoch 9/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.6201 - accuracy: 0.7894 - val_loss: 0.7177 - val_accuracy: 0.7682
# Epoch 10/10
# 391/391 [==============================] - 8s 19ms/step - loss: 0.6036 - accuracy: 0.7965 - val_loss: 0.6948 - val_accuracy: 0.7751
# Test loss: 0.6948485374450684
# Test accuracy: 0.7750999927520752

# %%
model = Sequential()
model.add(Conv2D(32, (5, 5), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (5, 5)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (5, 5)))
model.add(Activation('relu'))
model.add(Conv2D(64, (5, 5)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_31 (Conv2D)          (None, 28, 28, 32)        2432
#
#  activation_34 (Activation)  (None, 28, 28, 32)        0
#
#  conv2d_32 (Conv2D)          (None, 24, 24, 32)        25632
#
#  activation_35 (Activation)  (None, 24, 24, 32)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 12, 12, 32)       0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 12, 12, 32)        0
#
#  conv2d_33 (Conv2D)          (None, 8, 8, 64)          51264
#
#  activation_36 (Activation)  (None, 8, 8, 64)          0
#
#  conv2d_34 (Conv2D)          (None, 4, 4, 64)          102464
#
#  activation_37 (Activation)  (None, 4, 4, 64)          0
#
#  max_pooling2d_14 (MaxPoolin  (None, 2, 2, 64)         0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 2, 2, 64)          0
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 512)               131584
#
#  activation_38 (Activation)  (None, 512)               0
#
#  dropout_21 (Dropout)        (None, 512)               0
#
#  dense_12 (Dense)            (None, 10)                5130
#
#  activation_39 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 318,506
# Trainable params: 318,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 5s 11ms/step - loss: 1.9431 - accuracy: 0.2870 - val_loss: 1.5024 - val_accuracy: 0.4496
# Epoch 2/10
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5126 - accuracy: 0.4566 - val_loss: 1.4215 - val_accuracy: 0.4880
# Epoch 3/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.3304 - accuracy: 0.5290 - val_loss: 1.1626 - val_accuracy: 0.5933
# Epoch 4/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.2062 - accuracy: 0.5762 - val_loss: 1.1743 - val_accuracy: 0.5857
# Epoch 5/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.1093 - accuracy: 0.6134 - val_loss: 1.0985 - val_accuracy: 0.6243
# Epoch 6/10
# 391/391 [==============================] - 4s 10ms/step - loss: 1.0445 - accuracy: 0.6380 - val_loss: 1.2432 - val_accuracy: 0.5867
# Epoch 7/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.9848 - accuracy: 0.6581 - val_loss: 1.0293 - val_accuracy: 0.6447
# Epoch 8/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.9403 - accuracy: 0.6751 - val_loss: 1.1917 - val_accuracy: 0.6137
# Epoch 9/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.9082 - accuracy: 0.6847 - val_loss: 0.9841 - val_accuracy: 0.6769
# Epoch 10/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.8768 - accuracy: 0.6981 - val_loss: 0.9380 - val_accuracy: 0.6878
# Test loss: 0.9379585981369019
# Test accuracy: 0.6877999901771545

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_57 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_72 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_58 (Conv2D)          (None, 30, 30, 32)        9248
#
#  activation_73 (Activation)  (None, 30, 30, 32)        0
#
#  average_pooling2d (AverageP  (None, 15, 15, 32)       0
#  ooling2D)
#
#  dropout_37 (Dropout)        (None, 15, 15, 32)        0
#
#  conv2d_59 (Conv2D)          (None, 15, 15, 64)        18496
#
#  activation_74 (Activation)  (None, 15, 15, 64)        0
#
#  conv2d_60 (Conv2D)          (None, 13, 13, 64)        36928
#
#  activation_75 (Activation)  (None, 13, 13, 64)        0
#
#  average_pooling2d_1 (Averag  (None, 6, 6, 64)         0
#  ePooling2D)
#
#  dropout_38 (Dropout)        (None, 6, 6, 64)          0
#
#  flatten_10 (Flatten)        (None, 2304)              0
#
#  dense_23 (Dense)            (None, 512)               1180160
#
#  activation_76 (Activation)  (None, 512)               0
#
#  dropout_39 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 10)                5130
#
#  activation_77 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.7967 - accuracy: 0.3546 - val_loss: 1.6323 - val_accuracy: 0.4359
# Epoch 2/10
# 391/391 [==============================] - 5s 12ms/step - loss: 1.3891 - accuracy: 0.5054 - val_loss: 1.1869 - val_accuracy: 0.5830
# Epoch 3/10
# 391/391 [==============================] - 5s 12ms/step - loss: 1.2103 - accuracy: 0.5707 - val_loss: 1.0879 - val_accuracy: 0.6111
# Epoch 4/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.0836 - accuracy: 0.6212 - val_loss: 0.9543 - val_accuracy: 0.6650
# Epoch 5/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.9805 - accuracy: 0.6568 - val_loss: 0.9091 - val_accuracy: 0.6895
# Epoch 6/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.9046 - accuracy: 0.6847 - val_loss: 0.8642 - val_accuracy: 0.7009
# Epoch 7/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.8429 - accuracy: 0.7046 - val_loss: 0.7898 - val_accuracy: 0.7286
# Epoch 8/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.7914 - accuracy: 0.7240 - val_loss: 0.7814 - val_accuracy: 0.7348
# Epoch 9/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.7467 - accuracy: 0.7412 - val_loss: 0.7405 - val_accuracy: 0.7444
# Epoch 10/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.7103 - accuracy: 0.7554 - val_loss: 0.7533 - val_accuracy: 0.7446
# Test loss: 0.7533471584320068
# Test accuracy: 0.7445999979972839
